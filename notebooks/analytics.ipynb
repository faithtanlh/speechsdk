# %% [markdown]
# *This notebook primarily makes use of azure.ai.textanalytics classes, to meet the analytical requirements of this capstone project.*

# %%
import re
import textgrid

def extract_text_from_textgrid(file_path, tier_name=None):
    # Load the TextGrid file
    tg = textgrid.TextGrid.fromFile(file_path)
    
    # Find the relevant tier (if tier_name is provided)
    if tier_name:
        tier = tg.getFirst(tier_name)
    else:
        # If no specific tier is mentioned, extract from the first tier
        tier = tg[0]

    # Extract the intervals with text and concatenate them
    extracted_text = []
    for interval in tier:
        if interval.mark.strip():  # Only consider non-empty intervals
            extracted_text.append(interval.mark)
    
    # Return all the concatenated text
    return " ".join(extracted_text)

def remove_intents(text):
    """
    Remove intents marked by <UNSURE>, <UNIN/>, etc. from the text.
    """
    # Regular expression pattern to match any text within angle brackets including the brackets
    pattern = r'<[^>]*>'
    # Use re.sub to replace matches with an empty string
    cleaned_text = re.sub(pattern, '', text)
    # Optionally, you can remove extra spaces left after removing tags
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    return cleaned_text

# %%
import os
import time
from dotenv import load_dotenv
import azure.cognitiveservices.speech as speechsdk

# %%
# Set up subscription info for the Speech Service
load_dotenv() # Load environment variables such as Speech SDK API keys
AZURE_SPEECH_KEY = os.getenv("SPEECHSDK_API_KEY")
AZURE_SERVICE_REGION = os.getenv("SPEECHSDK_REGION")

# %%
# Initialize Speech Service
def initialize_speech_service(audio_file_path):
    # speech_config = speechsdk.SpeechConfig(subscription=AZURE_SPEECH_KEY, region=AZURE_SERVICE_REGION)
    speech_config = speechsdk.SpeechConfig(subscription=AZURE_SPEECH_KEY, region=AZURE_SERVICE_REGION)
    audio_config = speechsdk.audio.AudioConfig(filename=audio_file_path)
    return speechsdk.SpeechRecognizer(speech_config=speech_config, audio_config=audio_config)

# Perform transcription on the audio file
def transcribe_continuous_audio_file(recognizer):
    recognized_speech = []

    # Set a variable to manage the state of transcription
    done = False

    def handle_recognized(evt):
        print(f"Recognized: {evt.result.text}")
        recognized_speech.append(evt.result.text)
    
    def handle_canceled(evt):
        print(f"Recognition canceled: {evt.result.reason}")
        if evt.result.reason == speechsdk.CancellationReason.Error:
            print(f"Error details: {evt.result.error_details}")

        recognizer.stop_continuous_recognition()
        nonlocal done
        done = True

    # Attach handlers for recognized results and any cancellations
    recognizer.recognized.connect(handle_recognized)
    recognizer.canceled.connect(handle_canceled)
    
    # Start continuous recognition
    recognizer.start_continuous_recognition() # transcribe longer audio sessions or multiple sentences and handle the results asynchronously.
    print("Transcribing...")

    # Wait for completion (i.e., done = True)
    try:
        import time
        while not done:
            time.sleep(.5)
    except KeyboardInterrupt:
        print("Transcription stopped by user.")
        recognizer.stop_continuous_recognition()

    return " ".join(recognized_speech)  # Return all the transcriptions concatenated

# %% [markdown]
# ### Raw Transcription

# %%
recognizer = initialize_speech_service(r"C:\Users\zandr\OneDrive\Desktop\NUS Work\BT4103\faith-speechsdk\speechsdk\data\primock\day1_consultation01_doctor.wav") 
hypothesis_text = transcribe_continuous_audio_file(recognizer)
# Out:
# Transcribing...
# Recognized: Hello.
# Recognized: Hi. Yeah. OK. Hello. Good morning. So how can I help you this morning?
# Recognized: Yeah, I'm sorry to hear that. And when you say diarrhoea, what do you mean by diarrhea? Do you mean you're going to the toilet more often or are your stools more loose?
# Recognized: OK. And how many times a day are you going, let's say over the last couple of days?
# Recognized: 6-7 times a day and you mentioned this mainly water tree. Have you noticed any other things like blood in your stools?
# Recognized: OK. And you mentioned you've had some pain in your tummy as well. Whereabouts is the pain exactly?
# Recognized: One side. And what side is that?
# Recognized: That's right. OK. And can you describe the pain to me?
# Recognized: OK. And there's a pain. Is that is it there all the time or does it come and go?
# Recognized: Does the pain move anywhere else because on between your back?
# Recognized: OK, fine. And you mentioned you've been feeling quite weak and shaky as well. What do you mean by shaky? Do you mean you've been having, have you been feeling feverish, for example?
# Recognized: Measure your temperature then.
# Recognized: OK OK. Any other symptoms like sweating or night? No. And any vomiting at all?
# Recognized: You stop vomiting again and would you vomit? I know it's not nice thing to talk about but was it just normal food colour?
# Recognized: Yeah. And there was no blood in your vomits, is that right? No. OK. And any other symptoms at all? So you mentioned the tummy pain, you mentioned diarrhea, you mentioned the vomiting. Anything else that comes to mind?
# Recognized: OK.
# Recognized: OK, so you're drinking fluids. What kind of foods have you managed to eat? Anything?
# Recognized: OK, fine. And so we started three days ago. The symptoms, are you aware of any triggers which may have caused the symptoms to kick on? So for example, things like take away foods or eating out or being around other people who would similar symptoms?
# Recognized: Thank you. Do you remember where you ate?
# Recognized: OK anyone else unwell with similar symptoms?
# Recognized: OK, OK, fine.
# Recognized: Right. And in terms of your your overall health, are you normally fitting well or?
# Recognized: OK. And did you asthma well controlled?
# Recognized: And you don't have any other tummy problem? Bowel problems I should be aware of, no. OK. And apart from the inhalers, do you take any other medications?
# Recognized: OK, fine. And in terms of just your your day-to-day life, you said it's been affecting your life. In what way has it been affecting your life?
# Recognized: OK.
# Recognized: Yeah.
# Recognized: And have you are you currently working at the moment?
# Recognized: Would work.
# Recognized: OK. Have you been going into work the last three days? Have you been at home?
# Recognized: OK, that must be difficult for you then.
# Recognized: And you said, you mentioned you live with a wife and two children. Is that right? All right, just a couple of other questions we need to ask. Do you smoke at all?
# Recognized: And do you drink much more of alcohol?
# Recognized: OK, so.
# Recognized: Normally at this stage I'd like to examine you if that's OK but but haven't listened to your stories. I think just to recap, for the last three days you've been having loose dual diarrhea, bit of tummy pain mainly on the left hand side and vomiting and feeling quite weak and lethargic. You mentioned you're having this Chinese take away as well three days ago and I wonder whether that might be the cause of your problems. It seems like you may have something.
# Recognized: Called gastroenteritis.
# Recognized: Which is essentially just the tummy bug or infection of your of your tummy.
# Recognized: Mainly caused by viruses, but they can be a possibility of bacteria causing your symptoms.
# Recognized: At this stage, what what we'd recommend is just what we say conservative management. So I don't think you need anything like antibiotics is really just making sure you're well hydrated, so drinking plenty of fluids.
# Recognized: There are things like diolite you can get from the pharmacy which it's it helps replenish some of your minerals and vitamins.
# Recognized: And if you are having vomiting and diarrhea, I would soon recommend that first, you know, first couple of days. If you are feeling feverish and weak, taking some paracetamol, 2 tablets up to four times a day for the first few days can also help. I'll certainly advise you to take some time at work. Actually I know you're quite keen to work. I would say next to two to three days as clears from your system. Take some time off from rest.
# Recognized: You know, if your symptoms haven't got better, you know, in in three to four days, I'd like to come back and see you again.
# Recognized: Because if it is ongoing, then we have to wonder whether there's something else causing symptoms and we may need to do further tests like taking a sample of your store so we can test that, etcetera, etcetera.
# Recognized: How's that sound?
# Recognized: Do you have any questions for me?
# Recognized: OK. Is, is the treatment plan clear?
# Recognized: Great. Well, I wish you all the best. Thank you. Bye. Bye.
# Recognized: Bye.
# Recognition canceled: ResultReason.Canceled

# %% [markdown]
# ### Summarizing with `AbstractiveSummary `

# %%
text_analytics_key = os.getenv("text_analytics_key")
text_analytics_endpoint = os.getenv("text_analytics_endpoint")

# %%
from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

# authenticate client
def authenticate_client():
    ta_credential = AzureKeyCredential(str(text_analytics_key))
    text_analytics_client = TextAnalyticsClient(
        endpoint=str(text_analytics_endpoint),
        credential=ta_credential)
    return text_analytics_client

client = authenticate_client()

# %%
hypothesis_text_list = hypothesis_text.lower().split('. ')
print(hypothesis_text_list)
# remove predefined list of common unmeaningful words
words_to_remove = ['ok', 'yeah', 'yea', 'ya', 'hello', 'hi', 'bye', 'oh']

hypothesis_text_list_cleaned = [word.strip() for word in hypothesis_text_list if word.strip().lower() not in map(str.lower, words_to_remove)]
print(hypothesis_text_list_cleaned)
# Out:
# ['hello', 'hi', 'yeah', 'ok', 'hello', 'good morning', "so how can i help you this morning? yeah, i'm sorry to hear that", "and when you say diarrhoea, what do you mean by diarrhea? do you mean you're going to the toilet more often or are your stools more loose? ok", "and how many times a day are you going, let's say over the last couple of days? 6-7 times a day and you mentioned this mainly water tree", 'have you noticed any other things like blood in your stools? ok', "and you mentioned you've had some pain in your tummy as well", 'whereabouts is the pain exactly? one side', "and what side is that? that's right", 'ok', 'and can you describe the pain to me? ok', "and there's a pain", 'is that is it there all the time or does it come and go? does the pain move anywhere else because on between your back? ok, fine', "and you mentioned you've been feeling quite weak and shaky as well", "what do you mean by shaky? do you mean you've been having, have you been feeling feverish, for example? measure your temperature then", 'ok ok', 'any other symptoms like sweating or night? no', "and any vomiting at all? you stop vomiting again and would you vomit? i know it's not nice thing to talk about but was it just normal food colour? yeah", 'and there was no blood in your vomits, is that right? no', 'ok', 'and any other symptoms at all? so you mentioned the tummy pain, you mentioned diarrhea, you mentioned the vomiting', 'anything else that comes to mind? ok', "ok, so you're drinking fluids", 'what kind of foods have you managed to eat? anything? ok, fine', 'and so we started three days ago', 'the symptoms, are you aware of any triggers which may have caused the symptoms to kick on? so for example, things like take away foods or eating out or being around other people who would similar symptoms? thank you', 'do you remember where you ate? ok anyone else unwell with similar symptoms? ok, ok, fine', 'right', 'and in terms of your your overall health, are you normally fitting well or? ok', "and did you asthma well controlled? and you don't have any other tummy problem? bowel problems i should be aware of, no", 'ok', 'and apart from the inhalers, do you take any other medications? ok, fine', "and in terms of just your your day-to-day life, you said it's been affecting your life", 'in what way has it been affecting your life? ok', 'yeah', 'and have you are you currently working at the moment? would work', 'ok', 'have you been going into work the last three days? have you been at home? ok, that must be difficult for you then', 'and you said, you mentioned you live with a wife and two children', 'is that right? all right, just a couple of other questions we need to ask', 'do you smoke at all? and do you drink much more of alcohol? ok, so', "normally at this stage i'd like to examine you if that's ok but but haven't listened to your stories", "i think just to recap, for the last three days you've been having loose dual diarrhea, bit of tummy pain mainly on the left hand side and vomiting and feeling quite weak and lethargic", "you mentioned you're having this chinese take away as well three days ago and i wonder whether that might be the cause of your problems", 'it seems like you may have something', 'called gastroenteritis', 'which is essentially just the tummy bug or infection of your of your tummy', 'mainly caused by viruses, but they can be a possibility of bacteria causing your symptoms', "at this stage, what what we'd recommend is just what we say conservative management", "so i don't think you need anything like antibiotics is really just making sure you're well hydrated, so drinking plenty of fluids", "there are things like diolite you can get from the pharmacy which it's it helps replenish some of your minerals and vitamins", 'and if you are having vomiting and diarrhea, i would soon recommend that first, you know, first couple of days', 'if you are feeling feverish and weak, taking some paracetamol, 2 tablets up to four times a day for th ...
# ['good morning', "so how can i help you this morning? yeah, i'm sorry to hear that", "and when you say diarrhoea, what do you mean by diarrhea? do you mean you're going to the toilet more often or are your stools more loose? ok", "and how many times a day are you going, let's say over the last couple of days? 6-7 times a day and you mentioned this mainly water tree", 'have you noticed any other things like blood in your stools? ok', "and you mentioned you've had some pain in your tummy as well", 'whereabouts is the pain exactly? one side', "and what side is that? that's right", 'and can you describe the pain to me? ok', "and there's a pain", 'is that is it there all the time or does it come and go? does the pain move anywhere else because on between your back? ok, fine', "and you mentioned you've been feeling quite weak and shaky as well", "what do you mean by shaky? do you mean you've been having, have you been feeling feverish, for example? measure your temperature then", 'ok ok', 'any other symptoms like sweating or night? no', "and any vomiting at all? you stop vomiting again and would you vomit? i know it's not nice thing to talk about but was it just normal food colour? yeah", 'and there was no blood in your vomits, is that right? no', 'and any other symptoms at all? so you mentioned the tummy pain, you mentioned diarrhea, you mentioned the vomiting', 'anything else that comes to mind? ok', "ok, so you're drinking fluids", 'what kind of foods have you managed to eat? anything? ok, fine', 'and so we started three days ago', 'the symptoms, are you aware of any triggers which may have caused the symptoms to kick on? so for example, things like take away foods or eating out or being around other people who would similar symptoms? thank you', 'do you remember where you ate? ok anyone else unwell with similar symptoms? ok, ok, fine', 'right', 'and in terms of your your overall health, are you normally fitting well or? ok', "and did you asthma well controlled? and you don't have any other tummy problem? bowel problems i should be aware of, no", 'and apart from the inhalers, do you take any other medications? ok, fine', "and in terms of just your your day-to-day life, you said it's been affecting your life", 'in what way has it been affecting your life? ok', 'and have you are you currently working at the moment? would work', 'have you been going into work the last three days? have you been at home? ok, that must be difficult for you then', 'and you said, you mentioned you live with a wife and two children', 'is that right? all right, just a couple of other questions we need to ask', 'do you smoke at all? and do you drink much more of alcohol? ok, so', "normally at this stage i'd like to examine you if that's ok but but haven't listened to your stories", "i think just to recap, for the last three days you've been having loose dual diarrhea, bit of tummy pain mainly on the left hand side and vomiting and feeling quite weak and lethargic", "you mentioned you're having this chinese take away as well three days ago and i wonder whether that might be the cause of your problems", 'it seems like you may have something', 'called gastroenteritis', 'which is essentially just the tummy bug or infection of your of your tummy', 'mainly caused by viruses, but they can be a possibility of bacteria causing your symptoms', "at this stage, what what we'd recommend is just what we say conservative management", "so i don't think you need anything like antibiotics is really just making sure you're well hydrated, so drinking plenty of fluids", "there are things like diolite you can get from the pharmacy which it's it helps replenish some of your minerals and vitamins", 'and if you are having vomiting and diarrhea, i would soon recommend that first, you know, first couple of days', 'if you are feeling feverish and weak, taking some paracetamol, 2 tablets up to four times a day for the first few days can also help', "i'll certainly advise you to take so ...

# %%
# remove those very short sentences

long_hypothesis_text_list_cleaned = []
for sentence in hypothesis_text_list_cleaned:
    sentence_list = sentence.split(" ")
    if len(sentence_list) > 10:
        long_hypothesis_text_list_cleaned.append(sentence)

long_hypothesis_text_list_cleaned
# Out:
# ["so how can i help you this morning? yeah, i'm sorry to hear that",
#  "and when you say diarrhoea, what do you mean by diarrhea? do you mean you're going to the toilet more often or are your stools more loose? ok",
#  "and how many times a day are you going, let's say over the last couple of days? 6-7 times a day and you mentioned this mainly water tree",
#  'have you noticed any other things like blood in your stools? ok',
#  "and you mentioned you've had some pain in your tummy as well",
#  'is that is it there all the time or does it come and go? does the pain move anywhere else because on between your back? ok, fine',
#  "and you mentioned you've been feeling quite weak and shaky as well",
#  "what do you mean by shaky? do you mean you've been having, have you been feeling feverish, for example? measure your temperature then",
#  "and any vomiting at all? you stop vomiting again and would you vomit? i know it's not nice thing to talk about but was it just normal food colour? yeah",
#  'and there was no blood in your vomits, is that right? no',
#  'and any other symptoms at all? so you mentioned the tummy pain, you mentioned diarrhea, you mentioned the vomiting',
#  'what kind of foods have you managed to eat? anything? ok, fine',
#  'the symptoms, are you aware of any triggers which may have caused the symptoms to kick on? so for example, things like take away foods or eating out or being around other people who would similar symptoms? thank you',
#  'do you remember where you ate? ok anyone else unwell with similar symptoms? ok, ok, fine',
#  'and in terms of your your overall health, are you normally fitting well or? ok',
#  "and did you asthma well controlled? and you don't have any other tummy problem? bowel problems i should be aware of, no",
#  'and apart from the inhalers, do you take any other medications? ok, fine',
#  "and in terms of just your your day-to-day life, you said it's been affecting your life",
#  'and have you are you currently working at the moment? would work',
#  'have you been going into work the last three days? have you been at home? ok, that must be difficult for you then',
#  'and you said, you mentioned you live with a wife and two children',
#  'is that right? all right, just a couple of other questions we need to ask',
#  'do you smoke at all? and do you drink much more of alcohol? ok, so',
#  "normally at this stage i'd like to examine you if that's ok but but haven't listened to your stories",
#  "i think just to recap, for the last three days you've been having loose dual diarrhea, bit of tummy pain mainly on the left hand side and vomiting and feeling quite weak and lethargic",
#  "you mentioned you're having this chinese take away as well three days ago and i wonder whether that might be the cause of your problems",
#  'which is essentially just the tummy bug or infection of your of your tummy',
#  'mainly caused by viruses, but they can be a possibility of bacteria causing your symptoms',
#  "at this stage, what what we'd recommend is just what we say conservative management",
#  "so i don't think you need anything like antibiotics is really just making sure you're well hydrated, so drinking plenty of fluids",
#  "there are things like diolite you can get from the pharmacy which it's it helps replenish some of your minerals and vitamins",
#  'and if you are having vomiting and diarrhea, i would soon recommend that first, you know, first couple of days',
#  'if you are feeling feverish and weak, taking some paracetamol, 2 tablets up to four times a day for the first few days can also help',
#  'i would say next to two to three days as clears from your system',
#  "you know, if your symptoms haven't got better, you know, in in three to four days, i'd like to come back and see you again",
#  "because if it is ongoing, then we have to wonder whether there's something else causing symptoms and we may need to do further tests like taking a sample of your store so we can test that, etcetera, etcetera",
#  "how's that sound? do you have any questions for me? ok"]

# %%
# join into 1 single string to produce 1 summary only. as the max records is 25, we may as well just combine everything into 1
combined_dialogue = " ".join(long_hypothesis_text_list_cleaned)
[combined_dialogue]
# Out:
# ["so how can i help you this morning? yeah, i'm sorry to hear that and when you say diarrhoea, what do you mean by diarrhea? do you mean you're going to the toilet more often or are your stools more loose? ok and how many times a day are you going, let's say over the last couple of days? 6-7 times a day and you mentioned this mainly water tree have you noticed any other things like blood in your stools? ok and you mentioned you've had some pain in your tummy as well is that is it there all the time or does it come and go? does the pain move anywhere else because on between your back? ok, fine and you mentioned you've been feeling quite weak and shaky as well what do you mean by shaky? do you mean you've been having, have you been feeling feverish, for example? measure your temperature then and any vomiting at all? you stop vomiting again and would you vomit? i know it's not nice thing to talk about but was it just normal food colour? yeah and there was no blood in your vomits, is that right? no and any other symptoms at all? so you mentioned the tummy pain, you mentioned diarrhea, you mentioned the vomiting what kind of foods have you managed to eat? anything? ok, fine the symptoms, are you aware of any triggers which may have caused the symptoms to kick on? so for example, things like take away foods or eating out or being around other people who would similar symptoms? thank you do you remember where you ate? ok anyone else unwell with similar symptoms? ok, ok, fine and in terms of your your overall health, are you normally fitting well or? ok and did you asthma well controlled? and you don't have any other tummy problem? bowel problems i should be aware of, no and apart from the inhalers, do you take any other medications? ok, fine and in terms of just your your day-to-day life, you said it's been affecting your life and have you are you currently working at the moment? would work have you been going into work the last three days? have you been at home? ok, that must be difficult for you then and you said, you mentioned you live with a wife and two children is that right? all right, just a couple of other questions we need to ask do you smoke at all? and do you drink much more of alcohol? ok, so normally at this stage i'd like to examine you if that's ok but but haven't listened to your stories i think just to recap, for the last three days you've been having loose dual diarrhea, bit of tummy pain mainly on the left hand side and vomiting and feeling quite weak and lethargic you mentioned you're having this chinese take away as well three days ago and i wonder whether that might be the cause of your problems which is essentially just the tummy bug or infection of your of your tummy mainly caused by viruses, but they can be a possibility of bacteria causing your symptoms at this stage, what what we'd recommend is just what we say conservative management so i don't think you need anything like antibiotics is really just making sure you're well hydrated, so drinking plenty of fluids there are things like diolite you can get from the pharmacy which it's it helps replenish some of your minerals and vitamins and if you are having vomiting and diarrhea, i would soon recommend that first, you know, first couple of days if you are feeling feverish and weak, taking some paracetamol, 2 tablets up to four times a day for the first few days can also help i would say next to two to three days as clears from your system you know, if your symptoms haven't got better, you know, in in three to four days, i'd like to come back and see you again because if it is ongoing, then we have to wonder whether there's something else causing symptoms and we may need to do further tests like taking a sample of your store so we can test that, etcetera, etcetera how's that sound? do you have any questions for me? ok"]

# %%
# endpoint = os.environ["text_analytics_endpoint"]
# key = os.environ["text_analytics_key"]
load_dotenv()
key = str(os.getenv("text_analytics_key"))
endpoint = str(os.getenv("text_analytics_endpoint"))

text_analytics_client = TextAnalyticsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(key),
)
poller = text_analytics_client.begin_abstract_summary([combined_dialogue])
abstract_summary_results = poller.result()
for result in abstract_summary_results:
    if result.kind == "AbstractiveSummarization":
        print("Summaries abstracted:")
        [print(f"{summary.text}\n") for summary in result.summaries]
    elif result.is_error is True:
        print("...Is an error with code '{}' and message '{}'".format(
            result.error.code, result.error.message
        ))
# Out:
# Summaries abstracted:
# The document is a conversation between a doctor and a patient who is experiencing various symptoms including diarrhea, stomach pain, weakness, and vomiting. The doctor asks a series of questions to understand the symptoms better, including the frequency of bathroom visits, the nature of the symptoms, and any potential triggers. The doctor also inquires about the patient's overall health, medication use, and lifestyle. The doctor suggests that the symptoms might be due to a stomach bug or infection, possibly caused by a Chinese take-away, and recommends conservative management, including hydration, paracetamol, and a few days of rest. If the symptoms persist, the doctor proposes a follow-up visit.

# %% [markdown]
# ### Sentiment Analysis with `TextAnalyticsClient`

# %%
result = text_analytics_client.analyze_sentiment([combined_dialogue], show_opinion_mining=True)
docs = [doc for doc in result if not doc.is_error]

print("Let's visualize the sentiment of each of these documents")
for idx, doc in enumerate(docs):
    print(f"Document text: {[combined_dialogue][idx]}")
    print(f"Overall sentiment: {doc.sentiment}")
# Out:
# Let's visualize the sentiment of each of these documents
# Document text: so how can i help you this morning? yeah, i'm sorry to hear that and when you say diarrhoea, what do you mean by diarrhea? do you mean you're going to the toilet more often or are your stools more loose? ok and how many times a day are you going, let's say over the last couple of days? 6-7 times a day and you mentioned this mainly water tree have you noticed any other things like blood in your stools? ok and you mentioned you've had some pain in your tummy as well is that is it there all the time or does it come and go? does the pain move anywhere else because on between your back? ok, fine and you mentioned you've been feeling quite weak and shaky as well what do you mean by shaky? do you mean you've been having, have you been feeling feverish, for example? measure your temperature then and any vomiting at all? you stop vomiting again and would you vomit? i know it's not nice thing to talk about but was it just normal food colour? yeah and there was no blood in your vomits, is that right? no and any other symptoms at all? so you mentioned the tummy pain, you mentioned diarrhea, you mentioned the vomiting what kind of foods have you managed to eat? anything? ok, fine the symptoms, are you aware of any triggers which may have caused the symptoms to kick on? so for example, things like take away foods or eating out or being around other people who would similar symptoms? thank you do you remember where you ate? ok anyone else unwell with similar symptoms? ok, ok, fine and in terms of your your overall health, are you normally fitting well or? ok and did you asthma well controlled? and you don't have any other tummy problem? bowel problems i should be aware of, no and apart from the inhalers, do you take any other medications? ok, fine and in terms of just your your day-to-day life, you said it's been affecting your life and have you are you currently working at the moment? would work have you been going into work the last three days? have you been at home? ok, that must be difficult for you then and you said, you mentioned you live with a wife and two children is that right? all right, just a couple of other questions we need to ask do you smoke at all? and do you drink much more of alcohol? ok, so normally at this stage i'd like to examine you if that's ok but but haven't listened to your stories i think just to recap, for the last three days you've been having loose dual diarrhea, bit of tummy pain mainly on the left hand side and vomiting and feeling quite weak and lethargic you mentioned you're having this chinese take away as well three days ago and i wonder whether that might be the cause of your problems which is essentially just the tummy bug or infection of your of your tummy mainly caused by viruses, but they can be a possibility of bacteria causing your symptoms at this stage, what what we'd recommend is just what we say conservative management so i don't think you need anything like antibiotics is really just making sure you're well hydrated, so drinking plenty of fluids there are things like diolite you can get from the pharmacy which it's it helps replenish some of your minerals and vitamins and if you are having vomiting and diarrhea, i would soon recommend that first, you know, first couple of days if you are feeling feverish and weak, taking some paracetamol, 2 tablets up to four times a day for the first few days can also help i would say next to two to three days as clears from your system you know, if your symptoms haven't got better, you know, in in three to four days, i'd like to come back and see you again because if it is ongoing, then we have to wonder whether there's something else causing symptoms and we may need to do further tests like taking a sample of your store so we can test that, etcetera, etcetera how's that sound? do you have any questions for me? ok
# Overall sentiment: mixed

# %% [markdown]
# ### `HealthcareEntityRelation` recognises healthcare entities.

# %%
from azure.ai.textanalytics import HealthcareEntityRelation

poller = text_analytics_client.begin_analyze_healthcare_entities([combined_dialogue])
result = poller.result()

docs = [doc for doc in result if not doc.is_error]

print("Let's first visualize the outputted healthcare result:")
for doc in docs:
    for entity in doc.entities:
        print(f"Entity: {entity.text}")
        print(f"...Normalized Text: {entity.normalized_text}")
        print(f"...Category: {entity.category}")
        print(f"...Subcategory: {entity.subcategory}")
        print(f"...Offset: {entity.offset}")
        print(f"...Confidence score: {entity.confidence_score}")
        if entity.data_sources is not None:
            print("...Data Sources:")
            for data_source in entity.data_sources:
                print(f"......Entity ID: {data_source.entity_id}")
                print(f"......Name: {data_source.name}")
        if entity.assertion is not None:
            print("...Assertion:")
            print(f"......Conditionality: {entity.assertion.conditionality}")
            print(f"......Certainty: {entity.assertion.certainty}")
            print(f"......Association: {entity.assertion.association}")
    for relation in doc.entity_relations:
        print(f"Relation of type: {relation.relation_type} has the following roles")
        for role in relation.roles:
            print(f"...Role '{role.name}' with entity '{role.entity.text}'")
    print("------------------------------------------")

print("Now, let's get all of medication dosage relations from the documents")
dosage_of_medication_relations = [
    entity_relation
    for doc in docs
    for entity_relation in doc.entity_relations if entity_relation.relation_type == HealthcareEntityRelation.DOSAGE_OF_MEDICATION
]
# Out:
# Let's first visualize the outputted healthcare result:
# Entity: morning
# ...Normalized Text: None
# ...Category: Time
# ...Subcategory: None
# ...Offset:

# ...Normalized Text: None
# ...Category: Time
# ...Subcategory: None
# ...Offset: 1949
# ...Confidence score: 0.89
# Entity: wife
# ...Normalized Text: None
# ...Category: LivingStatus
# ...Subcategory: None
# ...Offset: 2073
# ...Confidence score: 0.85
# Entity: children
# ...Normalized Text: Offspring
# ...Category: FamilyRelation
# ...Subcategory: None
# ...Offset: 2086
# ...Confidence score: 0.98
# ...Data Sources:
# ......Entity ID: C0680063
# ......Name: UMLS
# ......Entity ID: 0000013779
# ......Name: AOD
# ......Entity ID: 0000043202
# ......Name: CHV
# ......Entity ID: CHILD
# ......Name: HL7V3.0
# ......Entity ID: C42708
# ......Name: NCI
# ......Entity ID: 35230
# ......Name: PSY
# ......Entity ID: 160499008
# ......Name: SNOMEDCT_US
# Entity: smoke
# ...Normalized Text: None
# ...Category: SubstanceUse
# ...Subcategory: None
# ...Offset: 2176
# ...Confidence score: 0.94
# Entity: alcohol
# ...Normalized Text: None
# ...Category: SubstanceUse
# ...Subcategory: None
# ...Offset: 2220
# ...Confidence score: 0.96
# Entity: last three days
# ...Normalized Text: None
# ...Category: Time
# ...Subcategory: None
# ...Offset: 2368
# ...Confidence score: 0.99
# Entity: loose dual diarrhea
# ...Normalized Text: None
# ...Category: SymptomOrSign
# ...Subcategory: None
# ...Offset: 2403
# ...Confidence score: 0.78
# Entity: tummy pain
# ...Normalized Text: None
# ...Category: SymptomOrSign
# ...Subcategory: None
# ...Offset: 2431
# ...Confidence score: 0.99
# Entity: left
# ...Normalized Text: None
# ...Category: Direction
# ...Subcategory: None
# ...Offset: 2456
# ...Confidence score: 0.99
# Entity: hand
# ...Normalized Text: Hand
# ...Category: BodyStructure
# ...Subcategory: None
# ...Offset: 2461
# ...Confidence score: 0.99
# ...Data Sources:
# ......Entity ID: C0018563
# ......Name: UMLS
# ......Entity ID: 0000002469
# ......Name: AOD
# ......Entity ID: 0000005789
# ......Name: CHV
# ......Entity ID: 2715-5520
# ......Name: CSP
# ......Entity ID: 9712
# ......Name: FMA
# ......Entity ID: HAND
# ......Name: HL7V2.5
# ......Entity ID: U002075
# ......Name: LCH
# ......Entity ID: sh85058615
# ......Name: LCH_NW
# ......Entity ID: LP7279-5
# ......Name: LNC
# ......Entity ID: D006225
# ......Name: MSH
# ......Entity ID: C32712
# ......Name: NCI
# ......Entity ID: MTHU000072
# ......Name: OMIM
# ......Entity ID: 22200
# ......Name: PSY
# ......Entity ID: Xa8St
# ......Name: RCD
# ......Entity ID: T-Y8700
# ......Name: SNM
# ......Entity ID: T-D8700
# ......Name: SNMI
# ......Entity ID: 85562004
# ......Name: SNOMEDCT_US
# ......Entity ID: 9712
# ......Name: UWDA
# Entity: vomiting
# ...Normalized Text: Vomiting
# ...Category: SymptomOrSign
# ...Subcategory: None
# ...Offset: 2475
# ...Confidence score: 1.0
# ...Data Sources:
# ......Entity ID: C0042963
# ......Name: UMLS
# ......Entity ID: 0000005506
# ......Name: AOD
# ......Entity ID: BI00287
# ......Name: BI
# ......Entity ID: B04.2
# ......Name: CCC
# ......Entity ID: 1014480
# ......Name: CCPSS
# ......Entity ID: 0000013085
# ......Name: CHV
# ......Entity ID: 793
# ......Name: COSTAR
# ......Entity ID: 1248-4787
# ......Name: CSP
# ......Entity ID: VOMIT
# ......Name: CST
# ......Entity ID: U004425
# ......Name: DXP
# ......Entity ID: HP:0002013
# ......Name: HPO
# ......Entity ID: R11.10
# ......Name: ICD10CM
# ......Entity ID: b5106
# ......Name: ICF-CY
# ......Entity ID: 422400008
# ......Name: ICNP
# ......Entity ID: D10
# ......Name: ICPC
# ......Entity ID: D10
# ......Name: ICPC2EENG
# ......Entity ID: MTHU012494
# ......Name: ICPC2ICD10ENG
# ......Entity ID: D10004
# ......Name: ICPC2P
# ......Entity ID: U004996
# ......Name: LCH
# ......Entity ID: sh85144382
# ......Name: LCH_NW
# ......Entity ID: MTHU013530
# ......Name: LNC
# ......Entity ID: 10047700
# ......Name: MDR
# ......Entity ID: 293335
# ......Name: MEDCIN
# ......Entity ID: 489
# ......Name: MEDLINEPLUS
# ......Entity ID: D014839
# ......Name: MSH
# ......Entity ID: 787.0
# ......Name: MTHICD9
# ......Entity ID: 01771
# ......Name: NANDA-I
# ......Entity ID: C3442
# ......Name: NCI
# ......Entity ID: 211602
# ......Name: NOC
# ......Entity ID: MTHU000225
# ......Name: OMIM
# ......Entity ID: 56340
# ......Name: PSY
# ......Entity ID: XE0rA
# ......Name: RCD
# ......Entity ID: F-61570
# ......Name: SNM
# ......Entity ID: F-52770
# ......Name: SNMI
# ......Entity ID: 422400008
# ......Name: SNOMEDCT_US
# ......Entity ID: 0228
# ......Name: WHO
# Entity: quite
# ...Normalized Text: None
# ...Category: ConditionQualifier
# ...Subcategory: None
# ...Offset: 2496
# ...Confidence score: 0.61
# Entity: weak
# ...Normalized Text: Weakness
# ...Category: SymptomOrSign
# ...Subcategory: None
# ...Offset: 2502
# ...Confidence score: 1.0
# ...Data Sources:
# ......Entity ID: C3714552
# ......Name: UMLS
# ......Entity ID: BI00748
# ......Name: BI
# ......Entity ID: 1014560
# ......Name: CCPSS
# ......Entity ID: 0000015946
# ......Name: CHV
# ......Entity ID: 796
# ......Name: COSTAR
# ......Entity ID: MALAISE
# ......Name: CST
# ......Entity ID: U004455
# ......Name: DXP
# ......Entity ID: R53.1
# ......Name: ICD10CM
# ......Entity ID: 799.3
# ......Name: ICD9CM
# ......Entity ID: MTHU083380
# ......Name: ICPC2ICD10ENG
# ......Entity ID:
# Relation of type: BodySiteOfCondition has the following roles
# ...Role 'Condition' with entity 'pain'
# ...Role 'BodyStructure' with entity 'tummy'
# Relation of type: BodySiteOfCondition has the following roles
# ...Role 'Condition' with entity 'pain'
# ...Role 'BodyStructure' with entity 'back'
# Relation of type: QualifierOfCondition has the following roles
# ...Role 'Qualifier' with entity 'quite'
# ...Role 'Condition' with entity 'weak'
# Relation of type: QualifierOfCondition has the following roles
# ...Role 'Qualifier' with entity 'quite'
# ...Role 'Condition' with entity 'shaky'
# Relation of type: CourseOfCondition has the following roles
# ...Role 'Course' with entity 'stop'
# ...Role 'Condition' with entity 'vomiting'
# Relation of type: QualifierOfCondition has the following roles
# ...Role 'Condition' with entity 'asthma'
# ...Role 'Qualifier' with entity 'well controlled'
# Relation of type: TimeOfCondition has the following roles
# ...Role 'Time' with entity 'last three days'
# ...Role 'Condition' with entity 'loose dual diarrhea'
# Relation of type: TimeOfCondition has the following roles
# ...Role 'Time' with entity 'last three days'
# ...Role 'Condition' with entity 'tummy pain'
# Relation of type: BodySiteOfCondition has the following roles
# ...Role 'Condition' with entity 'tummy pain'
# ...Role 'BodyStructure' with entity 'hand'
# Relation of type: DirectionOfBodyStructure has the following roles
# ...Role 'Direction' with entity 'left'
# ...Role 'BodyStructure' with entity 'hand'
# Relation of type: QualifierOfCondition has the following roles
# ...Role 'Qualifier' with entity 'quite'
# ...Role 'Condition' with entity 'weak'
# Relation of type: QualifierOfCondition has the following roles
# ...Role 'Qualifier' with entity 'quite'
# ...Role 'Condition' with entity 'lethargic'
# Relation of type: BodySiteOfCondition has the following roles
# ...Role 'Condition' with entity 'tummy bug'
# ...Role 'BodyStructure' with entity 'tummy'
# Relation of type: BodySiteOfCondition has the following roles
# ...Role 'Condition' with entity 'infection'
# ...Role 'BodyStructure' with entity 'tummy'
# Relation of type: TimeOfTreatment has the following roles
# ...Role 'Treatment' with entity 'conservative management'
# ...Role 'Time' with entity 'first couple of days'
# Relation of type: TimeOfTreatment has the following roles
# ...Role 'Treatment' with entity 'conservative management'
# ...Role 'Time' with entity 'first few days'
# Relation of type: TimeOfTreatment has the following roles
# ...Role 'Treatment' with entity 'conservative management'
# ...Role 'Time' with entity 'three days'
# Relation of type: DosageOfMedication has the following roles
# ...Role 'Medication' with entity 'antibiotics'
# ...Role 'Dosage' with entity '2 tablets'
# Relation of type: TimeOfTreatment has the following roles
# ...Role 'Treatment' with entity 'drinking plenty of fluids'
# ...Role 'Time' with entity 'first couple of days'
# Relation of type: TimeOfTreatment has the following roles
# ...Role 'Treatment' with entity 'drinking plenty of fluids'
# ...Role 'Time' with entity 'first few days'
# Relation of type: TimeOfTreatment has the following roles
# ...Role 'Treatment' with entity 'drinking plenty of fluids'
# ...Role 'Time' with entity 'two'
# Relation of type: TimeOfTreatment has the following roles
# ...Role 'Treatment' with entity 'drinking plenty of fluids'
# ...Role 'Time' with entity 'three days'
# Relation of type: DosageOfMedication has the following roles
# ...Role 'Medication' with entity 'diolite'
# ...Role 'Dosage' with entity '2 tablets'
# Relation of type: DosageOfMedication has the following roles
# ...Role 'Medication' with entity 'minerals'
# ...Role 'Dosage' with entity '2 tablets'
# Relation of type: DosageOfMedication has the following roles
# ...Role 'Medication' with entity 'vitamins'
# ...Role 'Dosage' with entity '2 tablets'
# Relation of type: DosageOfMedication has the following roles
# ...Role 'Medication' with entity 'paracetamol'
# ...Role 'Dosage' with entity '2 tablets'
# Relation of type: FrequencyOfMedication has the following roles
# ...Role 'Medication' with entity 'paracetamol'
# ...Role 'Frequency' with entity 'four times a day'
# Relation of type: TimeOfMedication has the following roles
# ...Role 'Medication' with entity 'paracetamol'
# ...Role 'Time' with entity 'first few days'
# Relation of type: CourseOfCondition has the following roles
# ...Role 'Condition' with entity 'symptoms'
# ...Role 'Course' with entity 'better'
# Relation of type: CourseOfCondition has the following roles
# ...Role 'Course' with entity 'ongoing'
# ...Role 'Condition' with entity 'symptoms'
# ------------------------------------------
# Now, let's get all of medication dosage relations from the documents

# %% [markdown]
# Categorises entities, can be used for further analysis. See examples below.
# ```
# Entity: last couple of days
# ...Normalized Text: None
# ...Category: Time
# ...Subcategory: None
# ...Offset: 266
# ...Confidence score: 0.93
# Entity: 6-7 times a day
# ...Normalized Text: None
# ...Category: Frequency
# ...Subcategory: None
# ...Offset: 287
# ...Confidence score: 0.98
# Entity: blood in your stools
# ...Normalized Text: None
# ...Category: SymptomOrSign
# ...Subcategory: None
# ...Offset: 383
# ...Confidence score: 0.92
# ```
#
# Classification can be done with `begin_multi_label_classify` in future.

# %% [markdown]
# ### `recognize_entities`
# This can also be used for classification, similar to the above, except that this is not healthcare specific.

# %%
import typing

result = text_analytics_client.recognize_entities([combined_dialogue])
result = [review for review in result if not review.is_error]
organization_to_reviews: typing.Dict[str, typing.List[str]] = {}

for idx, review in enumerate(result):
    for entity in review.entities:
        print(f"Entity '{entity.text}' has category '{entity.category}'")
        if entity.category == 'Organization':
            organization_to_reviews.setdefault(entity.text, [])
            organization_to_reviews[entity.text].append([combined_dialogue][idx])

for organization, reviews in organization_to_reviews.items():
    print(
        "\n\nOrganization '{}' has left us the following review(s): {}".format(
            organization, "\n\n".join(reviews)
        )
    )
# Out:
# Entity 'this morning' has category 'DateTime'
# Entity 'toilet' has category 'Location'
# Entity 'stools' has category 'Product'
# Entity 'last couple of days' has category 'DateTime'
# Entity '6-7' has category 'Quantity'
# Entity 'a day' has category 'DateTime'
# Entity 'measure' has category 'Skill'
# Entity 'vomiting' has category 'Skill'
# Entity 'food' has category 'Product'
# Entity 'vomiting' has category 'Event'
# Entity 'foods' has category 'Product'
# Entity 'foods' has category 'Product'
# Entity 'people' has category 'PersonType'
# Entity 'ate' has category 'Skill'
# Entity 'asthma' has category 'Product'
# Entity 'bowel' has category 'Skill'
# Entity 'inhalers' has category 'Product'
# Entity 'medications' has category 'Product'
# Entity 'working' has category 'Skill'
# Entity 'at the moment' has category 'DateTime'
# Entity 'last three days' has category 'DateTime'
# Entity 'home' has category 'Location'
# Entity 'wife' has category 'PersonType'
# Entity 'two' has category 'Quantity'
# Entity 'children' has category 'PersonType'
# Entity 'alcohol' has category 'Product'
# Entity 'last three days' has category 'DateTime'
# Entity 'three days ago' has category 'DateTime'
# Entity 'antibiotics' has category 'Product'
# Entity 'diolite' has category 'Product'
# Entity 'pharmacy' has category 'Location'
# Entity 'first' has category 'Quantity'
# Entity 'first' has category 'Quantity'
# Entity 'couple of days' has category 'DateTime'
# Entity 'paracetamol' has category 'Product'
# Entity '2' has category 'Quantity'
# Entity 'tablets' has category 'Product'
# Entity 'four' has category 'Quantity'
# Entity 'a' has category 'DateTime'
# Entity 'day' has category 'DateTime'
# Entity 'first' has category 'Quantity'
# Entity 'few days' has category 'DateTime'
# Entity 'two to three days' has category 'DateTime'
# Entity 'three' has category 'Quantity'
# Entity 'four days' has category 'DateTime'
# Entity 'store' has category 'Location'
# Entity 'test' has category 'Skill'
